# %% [markdown]
# # Testando bibliotecas de IA em Python
#
# Este notebook testa numpy, pandas, matplotlib, scikit-learn e jupyter.

# %%
import numpy as np
print("numpy:", np.__version__)
a = np.array([1, 2, 3])
print("Array numpy:", a)
# Out:
# numpy: 2.2.5
# Array numpy: [1 2 3]

# %%
import pandas as pd
print("pandas:", pd.__version__)
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
print("DataFrame pandas:\n", df)
# Out:
# pandas: 2.2.3
# DataFrame pandas:
#     col1  col2
# 0     1     3
# 1     2     4

# %%
import matplotlib

print("matplotlib:", matplotlib.__version__)
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Teste matplotlib")
plt.show()
# Out:
# matplotlib: 3.10.3

# %%
import sklearn
print("scikit-learn:", sklearn.__version__)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
print("Modelo LinearRegression criado com sucesso!")
# Out:
# scikit-learn: 1.6.1
# Modelo LinearRegression criado com sucesso!
# Modelo LinearRegression criado com sucesso!

# %% [markdown]
# Se todas as células acima executarem sem erro, as bibliotecas estão funcionando corretamente.
